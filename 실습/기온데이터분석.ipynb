# %%
import csv
f=open('seoul.csv')
data= csv.reader(f)
print(data)
f.close()

# %%
import csv
f=open('report.csv')
data= csv.reader(f)
print(data)
f.close()

# %%
import csv
f= open('seoul.csv')
data=csv.reader(f)
for row in data:
    print(row)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['\t2002-06-01', '108', '20.2', '17.1', '24.8']
# ['\t2002-06-02', '108', '22.9', '15.3', '30']
# ['\t2002-06-03', '108', '23.4', '17.6', '29.1']
# ['\t2002-06-04', '108', '22.4', '18.2', '27.6']
# ['\t2002-06-05', '108', '25.2', '19.1', '31.4']
# ['\t2002-06-06', '108', '25.9', '21.2', '31.2']
# ['\t2002-06-07', '108', '25.2', '19.6', '30.6']
# ['\t2002-06-08', '108', '22.1', '19.4', '27.1']
# ['\t2002-06-09', '108', '22.8', '18.3', '28']
# ['\t2002-06-10', '108', '22.4', '20', '26.6']
# ['\t2002-06-11', '108', '21.9', '19', '26.8']
# ['\t2002-06-12', '108', '18.6', '16.6', '22.9']
# ['\t2002-06-13', '108', '19.7', '16', '24.4']
# ['\t2002-06-14', '108', '20.4', '16.4', '25']
# ['\t2002-06-15', '108', '20.6', '17.4', '24.8']
# ['\t2002-06-16', '108', '22.4', '15.7', '28.6']
# ['\t2002-06-17', '108', '23.2', '17.9', '28.4']
# ['\t2002-06-18', '108', '23.4', '19', '28.9']
# ['\t2002-06-19', '108', '22.3', '20.2', '26.2']
# ...

# %%
import csv
f= open('report.csv')
data=csv.reader(f)
for row in data:
    print(row)
f.close()
# Out:
# ['시점', '기온 (℃)', '기온 (℃)', '기온 (℃)', '기온 (℃)', '기온 (℃)', '강수량 (mm)', '상대습도 (%)', '상대습도 (%)', '평균해면기압 (hpa)', '이슬점온도 (℃)', '평균운량 (10%)', '일조시간 (hr)', '최심신적설 (㎝)', '바람 (m/s)', '바람 (m/s)', '바람 (m/s)']
# ['시점', '평균', '평균최고', '극점최고', '평균최저', '극점최저', '소계', '평균', '최소', '소계', '소계', '소계', '소계', '소계', '평균풍속', '최대풍속', '최대순간풍속']
# ['1961. 01', '-5.2', '-1.2', '5.2', '-9.6', '-16.5', '18', '65', '25', '1026.2', '-', '4.5', '158.5', '8.2', '2.3', '-', '-']
# ['1961. 02', '-0.9', '3.8', '12.7', '-5.3', '-14.2', '8.8', '62.3', '25', '1021.5', '-', '3.6', '174.4', '3.6', '2.7', '-', '-']
# ['1961. 03', '5.4', '11.1', '17', '0.7', '-4.9', '40.8', '63.6', '21', '1021.3', '-', '4.8', '212.8', '7.8', '2.8', '-', '-']
# ['1961. 04', '11.7', '17.4', '25', '6.5', '0.7', '102.2', '60.7', '24', '1015.7', '-', '4.5', '227.4', '-', '3.2', '-', '-']
# ['1961. 05', '17.3', '22.9', '30.1', '11.8', '4.2', '123.6', '66.6', '23', '1011.2', '-', '6.2', '225', '-', '2.5', '-', '-']
# ...

# %%
import csv
f= open('seoul.csv')
data=csv.reader(f)
header=next(data) #header 변수에 헤더 데이터행을 저장
print(header)  #header변수를 출력
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
f= open('seoul.csv')
data=csv.reader(f)
header=next(data) #header 변수에 헤더 데이터행을 저장
for row in data:
    print(row)
f.close()
# Out:
# ['\t2002-06-01', '108', '20.2', '17.1', '24.8']
# ['\t2002-06-02', '108', '22.9', '15.3', '30']
# ['\t2002-06-03', '108', '23.4', '17.6', '29.1']
# ['\t2002-06-04', '108', '22.4', '18.2', '27.6']
# ['\t2002-06-05', '108', '25.2', '19.1', '31.4']
# ['\t2002-06-06', '108', '25.9', '21.2', '31.2']
# ['\t2002-06-07', '108', '25.2', '19.6', '30.6']
# ['\t2002-06-08', '108', '22.1', '19.4', '27.1']
# ['\t2002-06-09', '108', '22.8', '18.3', '28']
# ['\t2002-06-10', '108', '22.4', '20', '26.6']
# ['\t2002-06-11', '108', '21.9', '19', '26.8']
# ['\t2002-06-12', '108', '18.6', '16.6', '22.9']
# ['\t2002-06-13', '108', '19.7', '16', '24.4']
# ['\t2002-06-14', '108', '20.4', '16.4', '25']
# ['\t2002-06-15', '108', '20.6', '17.4', '24.8']
# ['\t2002-06-16', '108', '22.4', '15.7', '28.6']
# ['\t2002-06-17', '108', '23.2', '17.9', '28.4']
# ['\t2002-06-18', '108', '23.4', '19', '28.9']
# ['\t2002-06-19', '108', '22.3', '20.2', '26.2']
# ['\t2002-06-20', '108', '22.2', '19.2', '26.1']
# ...
